# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
from pandas import DataFrame, Series
import seaborn as sns
import urllib.request
from PIL import Image
import concurrent.futures
from collections import OrderedDict
import torch
import torch.utils
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
from torch.utils.data import Dataset
import torchvision
from torchvision import models
import torchvision.transforms as transforms
import tensorflow as tf
import cv2
import requests
from io import BytesIO
from torch.utils.data import Dataset, DataLoader

import glob
import os
#from skimage import img_as_ubyte

# %%
Base_Aloe_Ferox_Dataset = pd.ExcelFile('BaseSet.xlsx')

# %%
Base_Set = {}
for sheet in Base_Aloe_Ferox_Dataset.sheet_names:
    df = Base_Aloe_Ferox_Dataset.parse(sheet)
    Base_Set[sheet] = df

flowers_base = Base_Set["FLOWERS"]
buds_base = Base_Set["BUDS"]
fruit_base = Base_Set["FRUIT"]
No_Evidence_Base = Base_Set["No Evidence"]

flowers_base.head()
# Out:
#          id          observed_on_string observed_on         time_observed_at  \
# 0   9865839  2017-06-24 3:22:22 PM SAST  2017-06-24  2017-06-24 13:22:22 UTC
# 1  10787160         2011-07-15 00:00:00  2011-07-15                      NaN
# 2  10787636         2011-07-29 00:00:00  2011-07-29                      NaN
# 3  10790153         2011-08-14 00:00:00  2011-08-14                      NaN
# 4  10799481         2012-05-26 00:00:00  2012-05-26                      NaN
#
#              time_zone  user_id         user_login          user_name  \
# 0  Africa/Johannesburg   764003         gabriel_15                NaN
# 1  Africa/Johannesburg   660426  outramps-tanniedi          Di Turner
# 2  Africa/Johannesburg   660426  outramps-tanniedi          Di Turner
# 3  Africa/Johannesburg     7682              nicky  Nicola van Berkel
# 4  Africa/Johannesburg   660426  outramps-tanniedi          Di Turner
#
#                 created_at               updated_at  ... species_guess  \
# 0  2018-02-15 07:32:45 UTC  2018-06-07 16:08:59 UTC  ...     Cape aloe
# 1  2011-07-18 12:28:39 UTC  2018-06-07 16:14:22 UTC  ...     Cape aloe
# 2  2011-08-02 01:09:32 UTC  2018-06-07 16:14:07 UTC  ...     Cape aloe
# 3  2011-09-01 07:26:07 UTC  2018-06-07 16:13:47 UTC  ...     Cape aloe
# 4  2012-06-15 01:15:18 UTC  2018-08-26 12:02:52 UTC  ...     Cape aloe
#
#   scientific_name common_name iconic_taxon_name  taxon_id taxon_family_name  \
# 0      Aloe ferox   Cape Aloe           Plantae    124412     Asphodelaceae
# 1      Aloe ferox   Cape Aloe           Plantae    124412     Asphodelaceae
# 2      Aloe ferox   Cape Aloe           Plantae    124412     Asphodelaceae
# 3      Aloe ferox   Cape Aloe           Plantae    124412     Asphodelaceae
# 4      Aloe ferox   Cape Aloe           Plantae    124412     Asphodelaceae
#
#   taxon_genus_name  taxon_species_name  taxon_subspecies_name  \
# 0             Aloe          Aloe ferox                    NaN
# 1             Aloe          Aloe ferox                    NaN
# 2             Aloe          Aloe ferox                    NaN
# 3             Aloe          Aloe ferox                    NaN
# 4             Aloe          Aloe ferox                    NaN
#
#    field:phenology (foa)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 50 columns]

# %%
buds_base.head()
# Out:
#          id          observed_on_string observed_on         time_observed_at  \
# 0   8154638      2017/04/30 7:56 AM EDT  2017-04-30  2017-04-30 11:56:00 UTC
# 1   9272972      2007/07/01 9:41 AM BST  2007-07-01  2007-07-01 08:41:00 UTC
# 2   9865839  2017-06-24 3:22:22 PM SAST  2017-06-24  2017-06-24 13:22:22 UTC
# 3  10787160         2011-07-15 00:00:00  2011-07-15                      NaN
# 4  10787636         2011-07-29 00:00:00  2011-07-29                      NaN
#
#                     time_zone  user_id         user_login      user_name  \
# 0  Eastern Time (US & Canada)      520       johnnybirder  Johnny Wilson
# 1               Europe/London   493784            mark185    Mark Wright
# 2         Africa/Johannesburg   764003         gabriel_15            NaN
# 3         Africa/Johannesburg   660426  outramps-tanniedi      Di Turner
# 4         Africa/Johannesburg   660426  outramps-tanniedi      Di Turner
#
#                 created_at               updated_at  ... scientific_name  \
# 0  2017-09-28 16:43:38 UTC  2018-06-07 16:12:02 UTC  ...      Aloe ferox
# 1  2017-12-27 13:16:33 UTC  2018-06-07 16:09:12 UTC  ...      Aloe ferox
# 2  2018-02-15 07:32:45 UTC  2018-06-07 16:08:59 UTC  ...      Aloe ferox
# 3  2011-07-18 12:28:39 UTC  2018-06-07 16:14:22 UTC  ...      Aloe ferox
# 4  2011-08-02 01:09:32 UTC  2018-06-07 16:14:07 UTC  ...      Aloe ferox
#
#   common_name iconic_taxon_name taxon_id  taxon_family_name taxon_genus_name  \
# 0   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 1   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 2   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 3   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 4   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
#
#   taxon_species_name  taxon_subspecies_name  taxon_variety_name  \
# 0         Aloe ferox                    NaN                 NaN
# 1         Aloe ferox                    NaN                 NaN
# 2         Aloe ferox                    NaN                 NaN
# 3         Aloe ferox                    NaN                 NaN
# 4         Aloe ferox                    NaN                 NaN
#
#    field:phenology (foa)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 51 columns]

# %%
fruit_base.head()
# Out:
#          id       observed_on_string observed_on         time_observed_at  \
# 0   9034202  2017/11/24 2:54 PM SAST  2017-11-24  2017-11-24 12:54:00 UTC
# 1  10832079      2012-10-12 00:00:00  2012-10-12                      NaN
# 2  10871050      2013-07-17 00:00:00  2013-07-17                      NaN
# 3  10875477      2013-09-25 00:00:00  2013-09-25                      NaN
# 4  10962203      2013-09-12 00:00:00  2013-09-12                      NaN
#
#              time_zone  user_id         user_login          user_name  \
# 0  Africa/Johannesburg   389997             shauns    Shaun Swanepoel
# 1  Africa/Johannesburg     7682              nicky  Nicola van Berkel
# 2  Africa/Johannesburg   660426  outramps-tanniedi          Di Turner
# 3  Africa/Johannesburg     7682              nicky  Nicola van Berkel
# 4  Africa/Johannesburg   383144         tonyrebelo        Tony Rebelo
#
#                 created_at               updated_at  ... scientific_name  \
# 0  2017-12-03 21:28:02 UTC  2018-08-26 11:58:10 UTC  ...      Aloe ferox
# 1  2012-11-30 08:16:37 UTC  2018-11-19 09:09:18 UTC  ...      Aloe ferox
# 2  2013-07-30 01:59:08 UTC  2018-11-19 09:09:51 UTC  ...      Aloe ferox
# 3  2013-10-17 17:28:07 UTC  2018-11-19 09:08:12 UTC  ...      Aloe ferox
# 4  2014-05-03 23:49:34 UTC  2023-10-13 09:04:15 UTC  ...      Aloe ferox
#
#   common_name iconic_taxon_name taxon_id  taxon_family_name taxon_genus_name  \
# 0   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 1   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 2   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 3   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 4   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
#
#   taxon_species_name  taxon_subspecies_name  taxon_variety_name  \
# 0         Aloe ferox                    NaN                 NaN
# 1         Aloe ferox                    NaN                 NaN
# 2         Aloe ferox                    NaN                 NaN
# 3         Aloe ferox                    NaN                 NaN
# 4         Aloe ferox                    NaN                 NaN
#
#    field:phenology (foa)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 51 columns]

# %%
No_Evidence_Base.head()
# Out:
#          id      observed_on_string observed_on         time_observed_at  \
# 0  11111885     2015-05-06 00:00:00  2015-05-06                      NaN
# 1  11197854     2015-11-20 00:00:00  2015-11-20                      NaN
# 2  11245126     2017-01-17 00:00:00  2017-01-17                      NaN
# 3  20173194     2017-06-24 00:00:00  2017-06-24                      NaN
# 4  27389400  2015/01/07 4:23 AM PST  2015-01-07  2015-01-07 12:23:00 UTC
#
#                     time_zone  user_id         user_login           user_name  \
# 0         Africa/Johannesburg   660426  outramps-tanniedi           Di Turner
# 1                    Pretoria   711873    benjamin_walton     Benjamin Walton
# 2         Africa/Johannesburg   664422      lizegreenieza  Lize van der Merwe
# 3                    Pretoria   389997             shauns     Shaun Swanepoel
# 4  Pacific Time (US & Canada)  1831095   douglasriverside     Douglas J. Long
#
#                 created_at               updated_at  ... scientific_name  \
# 0  2015-05-17 11:20:21 UTC  2023-05-26 11:54:43 UTC  ...      Aloe ferox
# 1  2016-01-27 11:54:52 UTC  2024-05-27 09:40:27 UTC  ...      Aloe ferox
# 2  2017-06-12 15:59:45 UTC  2023-09-06 10:04:38 UTC  ...      Aloe ferox
# 3  2017-08-16 08:05:05 UTC  2023-09-06 10:04:34 UTC  ...      Aloe ferox
# 4  2019-06-21 18:19:54 UTC  2020-10-11 11:04:47 UTC  ...      Aloe ferox
#
#   common_name iconic_taxon_name taxon_id  taxon_family_name taxon_genus_name  \
# 0   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 1   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 2   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 3   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
# 4   Cape Aloe           Plantae   124412      Asphodelaceae             Aloe
#
#   taxon_species_name  taxon_subspecies_name  taxon_variety_name  \
# 0         Aloe ferox                    NaN                 NaN
# 1         Aloe ferox                    NaN                 NaN
# 2         Aloe ferox                    NaN                 NaN
# 3         Aloe ferox                    NaN                 NaN
# 4         Aloe ferox                    NaN                 NaN
#
#    field:phenology (foa)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 51 columns]

# %%
def missing_values(df):
    print(f'Column\t\t\t% missing')
    print(f'{"-"}'*35) 
    return (df.isnull().sum()/len(df)*100
    ).astype(int)

missing_values(flowers_base)
# Out:
# Column			% missing
# -----------------------------------
# id                                    0
# observed_on_string                    0
# observed_on                           0
# time_observed_at                      7
# time_zone                             0
# user_id                               0
# user_login                            0
# user_name                             4
# created_at                            0
# updated_at                            0
# quality_grade                         0
# license                               5
# url                                   0
# image_url                             0
# sound_url                           100
# tag_list                             93
# description                          88
# num_identification_agreements         0
# num_identification_disagreements      0
# captive_cultivated                    0
# oauth_application_id                 88
# place_guess                           0
# latitude                              0
# longitude                             0
# positional_accuracy                  10
# private_place_guess                 100
# private_latitude                    100
# private_longitude                   100
# public_positional_accuracy           10
# geoprivacy                           99
# taxon_geoprivacy                      0
# coordinates_obscured                  0
# positioning_method                   95
# positioning_device                   95
# place_town_name                      99
# place_county_name                     0
# place_state_name                      0
# place_country_name                    0
# place_admin1_name                     0
# place_admin2_name                     0
# species_guess                         0
# scientific_name                       0
# common_name                           0
# iconic_taxon_name                     0
# taxon_id                              0
# taxon_family_name                     0
# taxon_genus_name                      0
# taxon_species_name                    0
# taxon_subspecies_name               100
# field:phenology (foa)                65
# dtype: int64

# %%
#all null columns or columns with 100% the same value have been removed
useful = ['id','observed_on','image_url','num_identification_agreements','latitude','longitude','field:phenology (foa)']

flowers_one= flowers_base[useful]
buds_one = buds_base[useful]
fruit_one = fruit_base[useful]
No_Evidence_one = No_Evidence_Base[useful]

flowers_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
buds_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
fruit_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
No_Evidence_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\884026182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flowers_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\884026182.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buds_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\884026182.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fruit_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\884026182.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   No_Evidence_one.rename(columns={'field:phenology (foa)':'phenology'}, inplace=True)

# %%
train_flowers = flowers_one[flowers_one.phenology.isnull()]
train_buds = buds_one[buds_one.phenology.isnull()]
train_fruit = fruit_one[fruit_one.phenology.isnull()]
train_No_Evidence = No_Evidence_one[No_Evidence_one.phenology.isnull()]

# %%
test_flowers = flowers_one[flowers_one.phenology.notnull()]
test_buds = buds_one[buds_one.phenology.notnull()]
test_fruit = fruit_one[fruit_one.phenology.notnull()]
test_No_Evidence = No_Evidence_one[No_Evidence_one.phenology.notnull()]

# %%
test_flowers.head()
#test_buds.head()
#test_fruit.head()
#test_No_Evidence.head()
# Out:
#             id observed_on                                          image_url  \
# 309  123502268  2022-06-16  https://inaturalist-open-data.s3.amazonaws.com...
# 311  124524639  2022-06-20  https://inaturalist-open-data.s3.amazonaws.com...
# 315  125585296  2022-07-09  https://inaturalist-open-data.s3.amazonaws.com...
# 316  125585317  2022-07-09  https://inaturalist-open-data.s3.amazonaws.com...
# 321  127508909  2022-07-22  https://inaturalist-open-data.s3.amazonaws.com...
#
#      num_identification_agreements   latitude  longitude       phenology
# 309                              1 -33.250185  26.967054  Flowers & Buds
# 311                              2 -33.068978  27.174663  Flowers & Buds
# 315                              1 -33.452610  26.635715         Flowers
# 316                              1 -33.430468  26.611436         Flowers
# 321                              1 -33.318718  26.670864         Flowers

# %%
train_flowers["phenology"]="Flowers"
train_buds["phenology"]="Buds"
train_fruit["phenology"]="Fruit"
train_No_Evidence["phenology"]="No Evidence"
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\1268193639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_flowers["phenology"]="Flowers"
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\1268193639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_buds["phenology"]="Buds"
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\1268193639.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_fruit["phenology"]="Fruit"
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\1268193639.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_No_Evidence["phenology"]="No Evidence"

# %%
Test_set = pd.concat([test_flowers, test_buds, test_fruit, test_No_Evidence], axis=0)
Train_set = pd.concat([train_flowers, train_buds, train_fruit, train_No_Evidence], axis=0)

Train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1862 entries, 0 to 620
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             1862 non-null   int64
#  1   observed_on                    1862 non-null   datetime64[ns]
#  2   image_url                      1862 non-null   object
#  3   num_identification_agreements  1862 non-null   int64
#  4   latitude                       1862 non-null   float64
#  5   longitude                      1862 non-null   float64
#  6   phenology                      1862 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 116.4+ KB

# %%
missing_values(Train_set)
# Out:
# Column			% missing
# -----------------------------------
# id                               0
# observed_on                      0
# image_url                        0
# num_identification_agreements    0
# latitude                         0
# longitude                        0
# phenology                        0
# dtype: int64

# %%
Train_set = Train_set.dropna()

Train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1862 entries, 0 to 620
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             1862 non-null   int64
#  1   observed_on                    1862 non-null   datetime64[ns]
#  2   image_url                      1862 non-null   object
#  3   num_identification_agreements  1862 non-null   int64
#  4   latitude                       1862 non-null   float64
#  5   longitude                      1862 non-null   float64
#  6   phenology                      1862 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 116.4+ KB

# %%
missing_values(Test_set)
# Out:
# Column			% missing
# -----------------------------------
# id                               0
# observed_on                      0
# image_url                        0
# num_identification_agreements    0
# latitude                         0
# longitude                        0
# phenology                        0
# dtype: int64

# %%
#Train_set.sort_values(by='phenology')

# %%
#Test_set.sort_values(by='phenology')

# %%
Train_set[Train_set.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, observed_on, image_url, num_identification_agreements, latitude, longitude, phenology]
# Index: []

# %%
Train_set.describe([x*0.1 for x in range(10)])
Test_set.describe([x*0.1 for x in range(10)])
# Out:
#                  id                    observed_on  \
# count  6.640000e+02                            664
# mean   1.696178e+08  2023-06-04 06:04:20.240963840
# min    1.195873e+08            2017-09-22 00:00:00
# 0%     1.195873e+08            2017-09-22 00:00:00
# 10%    1.344025e+08            2022-08-28 00:00:00
# 20%    1.688603e+08            2023-06-21 00:00:00
# 30%    1.711919e+08            2023-06-24 00:00:00
# 40%    1.715134e+08            2023-07-01 00:00:00
# 50%    1.719922e+08            2023-07-04 00:00:00
# 60%    1.736323e+08            2023-07-08 00:00:00
# 70%    1.813908e+08            2023-08-27 00:00:00
# 80%    1.814497e+08            2023-08-27 00:00:00
# 90%    1.815304e+08            2023-08-27 00:00:00
# max    1.836630e+08            2023-08-27 00:00:00
# std    1.654345e+07                            NaN
#
#        num_identification_agreements    latitude   longitude
# count                     664.000000  664.000000  664.000000
# mean                        1.293675  -32.940885   25.713149
# min                         1.000000  -33.833698   21.314178
# 0%                          1.000000  -33.833698   21.314178
# 10%                         1.000000  -33.521832   22.607768
# 20%                         1.000000  -33.501232   22.954928
# 30%                         1.000000  -33.474455   23.314697
# 40%                         1.000000  -33.387423   26.134647
# 50%                         1.000000  -33.292857   26.589494
# 60%                         1.000000  -33.125465   26.745219
# 70%                         1.000000  -33.055363   27.172231
# 80%                         2.000000  -32.580452   27.236731
# 90%                         2.000000  -31.933178   28.432355
# max                         3.000000  -29.627820   30.700312
# std                         0.484657    0.961627    2.473650

# %%
sns.displot(data =Train_set['latitude'])
sns.displot(data =Train_set['longitude'])

# %%
print(Test_set.index)
# Out:
# Index([309, 311, 315, 316, 321, 322, 333, 342, 344, 345,
#        ...
#        548, 551, 552, 553, 554, 555, 556, 557, 558, 579],
#       dtype='int64', length=664)

# %%
Train_set = Train_set.reset_index(drop=True)
Test_set = Test_set.reset_index(drop=True)

# %%
Test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             664 non-null    int64
#  1   observed_on                    664 non-null    datetime64[ns]
#  2   image_url                      664 non-null    object
#  3   num_identification_agreements  664 non-null    int64
#  4   latitude                       664 non-null    float64
#  5   longitude                      664 non-null    float64
#  6   phenology                      664 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 36.4+ KB

# %%
missing_values(Train_set)
# Out:
# Column			% missing
# -----------------------------------
# id                               0
# observed_on                      0
# image_url                        0
# num_identification_agreements    0
# latitude                         0
# longitude                        0
# phenology                        0
# dtype: int64

# %%
Train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1862 entries, 0 to 1861
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             1862 non-null   int64
#  1   observed_on                    1862 non-null   datetime64[ns]
#  2   image_url                      1862 non-null   object
#  3   num_identification_agreements  1862 non-null   int64
#  4   latitude                       1862 non-null   float64
#  5   longitude                      1862 non-null   float64
#  6   phenology                      1862 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 102.0+ KB

# %%
lastTrain_set = Train_set[['image_url','phenology']].copy()
lastTrain_set.head()
# Out:
#                                            image_url phenology
# 0  https://inaturalist-open-data.s3.amazonaws.com...   Flowers
# 1  https://inaturalist-open-data.s3.amazonaws.com...   Flowers
# 2  https://inaturalist-open-data.s3.amazonaws.com...   Flowers
# 3  https://inaturalist-open-data.s3.amazonaws.com...   Flowers
# 4  https://inaturalist-open-data.s3.amazonaws.com...   Flowers

# %%
def download_image(image_url, image_name_counter, folder):
    file_name = f"./{folder}/{image_name_counter}.png"
    urllib.request.urlretrieve(image_url, file_name)
    print(f"Downloaded {file_name}")

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(lambda x: download_image(x[1], x[0], "Train"), enumerate(lastTrain_set['image_url'], start=1))
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(lambda x: download_image(x[1], x[0], "Test"), enumerate(Test_set['image_url'], start=1))
# Out:
# Downloaded ./Train/3.png
# Downloaded ./Train/4.png
# Downloaded ./Train/2.png
# Downloaded ./Train/6.png
# Downloaded ./Train/5.png
# Downloaded ./Train/1.png
# Downloaded ./Train/7.png
# Downloaded ./Train/11.png
# Downloaded ./Train/9.png
# Downloaded ./Train/8.png
# Downloaded ./Train/15.png
# Downloaded ./Train/19.png
# Downloaded ./Train/18.png
# Downloaded ./Train/13.pngDownloaded ./Train/17.png
# Downloaded ./Train/14.png
#
# Downloaded ./Train/16.png
# Downloaded ./Train/22.png
# Downloaded ./Train/12.png
# Downloaded ./Train/21.png
# Downloaded ./Train/23.png
# Downloaded ./Train/20.png
# Downloaded ./Train/24.png
# Downloaded ./Train/25.png
# Downloaded ./Train/28.png
# Downloaded ./Train/27.png
# Downloaded ./Train/26.png
# Downloaded ./Train/31.png
# Downloaded ./Train/32.png
# Downloaded ./Train/30.png
# Downloaded ./Train/29.png
# Downloaded ./Train/35.png
# Downloaded ./Train/33.png
# Downloaded ./Train/34.png
# Downloaded ./Train/37.png
# Downloaded ./Train/36.png
# Downloaded ./Train/10.png
# Downloaded ./Train/38.png
# Downloaded ./Train/39.png
# Downloaded ./Train/40.png
# Downloaded ./Train/42.png
# Downloaded ./Train/41.png
# Downloaded ./Train/43.png
# Downloaded ./Train/48.png
# Downloaded ./Train/45.png
# Downloaded ./Train/46.png
# Downloaded ./Train/44.png
# Downloaded ./Train/47.png
# Downloaded ./Train/50.png
# Downloaded ./Train/49.png
# Downloaded ./Train/1751.png
# Downloaded ./Train/1748.png
# Downloaded ./Train/1750.png
# Downloaded ./Train/1755.png
# Downloaded ./Train/1752.png
# Downloaded ./Train/1753.png
# Downloaded ./Train/1742.png
# Downloaded ./Train/1754.png
# Downloaded ./Train/1756.png
# Downloaded ./Train/1749.png
# Downloaded ./Train/1757.png
# Downloaded ./Train/1758.png
# ...
# Downloaded ./Test/52.png
# Downloaded ./Test/53.png
# Downloaded ./Test/51.png
# Downloaded ./Test/40.png
# Downloaded ./Test/54.png
# Downloaded ./Test/55.png
# Downloaded ./Test/56.png
# Downloaded ./Test/46.png
# Downloaded ./Test/49.png
# Downloaded ./Test/58.png
# Downloaded ./Test/60.png
# Downloaded ./Test/61.png
# Downloaded ./Test/59.png
# Downloaded ./Test/62.png
# Downloaded ./Test/64.png
# Downloaded ./Test/63.png
# Downloaded ./Test/65.png
# Downloaded ./Test/67.png
# Downloaded ./Test/68.png
# Downloaded ./Test/69.png
# Downloaded ./Test/71.png
# Downloaded ./Test/70.png
# Downloaded ./Test/57.png
# Downloaded ./Test/73.png
# Downloaded ./Test/72.png
# Downloaded ./Test/75.png
# Downloaded ./Test/74.png
# Downloaded ./Test/76.png
# Downloaded ./Test/77.png
# Downloaded ./Test/66.png
# Downloaded ./Test/78.png
# Downloaded ./Test/80.png
# Downloaded ./Test/81.png
# Downloaded ./Test/79.png
# Downloaded ./Test/83.png
# Downloaded ./Test/82.png
# Downloaded ./Test/86.png
# Downloaded ./Test/84.png
# Downloaded ./Test/85.png
# Downloaded ./Test/88.png
# Downloaded ./Test/87.png
# Downloaded ./Test/89.png
# Downloaded ./Test/91.png
# Downloaded ./Test/90.png
# Downloaded ./Test/94.png
# Downloaded ./Test/92.png
# Downloaded ./Test/93.png
# Downloaded ./Test/95.png
# Downloaded ./Test/98.png
# Downloaded ./Test/96.png
# Downloaded ./Test/97.png
# Downloaded ./Test/100.png
# Downloaded ./Test/103.png
# Downloaded ./Test/107.png
# Downloaded ./Test/109.png
# Downloaded ./Test/106.png
# Downloaded ./Test/99.png
# Downloaded ./Test/101.png
# Downloaded ./Test/108.png
# Downloaded ./Test/113.png
# Downloaded ./Test/102.png
# Downloaded ./Test/105.png
# Downloaded ./Test/114.png
# Downloaded ./Test/104.png
# Downloaded ./Test/110.png
# Downloaded ./Test/116.png
# Downloaded ./Test/111.png
# Downloaded ./Test/112.png
# Downloaded ./Test/120.png
# Downloaded ./Test/118.png
# Downloaded ./Test/119.png
# Downloaded ./Test/121.png
# Downloaded ./Test/122.png
# Downloaded ./Test/124.png
# Downloaded ./Test/125.png
# Downloaded ./Test/126.png
# Downloaded ./Test/117.png
# Downloaded ./Test/128.png
# Downloaded ./Test/115.png
# Downloaded ./Test/133.png
# Downloaded ./Test/123.png
# Downloaded ./Test/134.png
# Downloaded ./Test/135.png
# Downloaded ./Test/127.png
# Downloaded ./Test/136.png
# Downloaded ./Test/137.png
# Downloaded ./Test/138.png
# Downloaded ./Test/129.png
# Downloaded ./Test/132.png
# Downloaded ./Test/346.png
# Downloaded ./Test/336.png
# Downloaded ./Test/339.png
# Downloaded ./Test/335.png
# Downloaded ./Test/347.png
# Downloaded ./Test/349.png
# Downloaded ./Test/348.png
# Downloaded ./Test/337.png
# Downloaded ./Test/352.png
# Downloaded ./Test/355.png
# Downloaded ./Test/353.png
# Downloaded ./Test/351.png
# Downloaded ./Test/350.png
# Downloaded ./Test/363.png
# Downloaded ./Test/354.png
# Downloaded ./Test/357.png
# Downloaded ./Test/361.png
# Downloaded ./Test/362.png
# Downloaded ./Test/359.png
# Downloaded ./Test/358.png
# Downloaded ./Test/364.png
# Downloaded ./Test/360.png
# Downloaded ./Test/356.png
# Downloaded ./Test/366.png
# Downloaded ./Test/368.png
# Downloaded ./Test/369.png
# Downloaded ./Test/374.png
# Downloaded ./Test/373.png
# Downloaded ./Test/365.png
# Downloaded ./Test/372.pngDownloaded ./Test/370.png
# Downloaded ./Test/371.png
#
# Downloaded ./Test/367.png
# Downloaded ./Test/376.png
# Downloaded ./Test/375.png
# Downloaded ./Test/377.png
# Downloaded ./Test/378.png
# Downloaded ./Test/381.png
# Downloaded ./Test/382.png
# Downloaded ./Test/379.png
# Downloaded ./Test/380.png
# Downloaded ./Test/384.png
# Downloaded ./Test/385.png
# Downloaded ./Test/383.png
# Downloaded ./Test/387.png
# Downloaded ./Test/386.png
# Downloaded ./Test/389.png
# Downloaded ./Test/388.png
# Downloaded ./Test/390.png
# Downloaded ./Test/392.png
# Downloaded ./Test/391.png
# Downloaded ./Test/394.png
# Downloaded ./Test/403.png
# Downloaded ./Test/405.png
# Downloaded ./Test/406.png
# Downloaded ./Test/396.png
# Downloaded ./Test/401.png
# Downloaded ./Test/402.png
# Downloaded ./Test/399.png
# Downloaded ./Test/398.pngDownloaded ./Test/395.png
#
# Downloaded ./Test/404.png
# Downloaded ./Test/393.png
# Downloaded ./Test/397.png
# Downloaded ./Test/400.png
# Downloaded ./Test/407.png
# Downloaded ./Test/409.png
# Downloaded ./Test/408.png
# Downloaded ./Test/410.png
# Downloaded ./Test/413.png
# Downloaded ./Test/415.png
# Downloaded ./Test/414.png
# Downloaded ./Test/416.png
# Downloaded ./Test/418.png
# Downloaded ./Test/417.png
# Downloaded ./Test/419.png
# Downloaded ./Test/421.png
# Downloaded ./Test/420.png
# Downloaded ./Test/424.png
# Downloaded ./Test/422.png
# Downloaded ./Test/423.png
# Downloaded ./Test/426.pngDownloaded ./Test/412.png
#
# Downloaded ./Test/427.png
# Downloaded ./Test/411.png
# Downloaded ./Test/425.png
# Downloaded ./Test/428.png
# Downloaded ./Test/429.png
# Downloaded ./Test/430.png
# Downloaded ./Test/431.png
# Downloaded ./Test/432.png
# Downloaded ./Test/434.png
# Downloaded ./Test/433.png
# Downloaded ./Test/435.png
# Downloaded ./Test/437.png
# Downloaded ./Test/436.png
# Downloaded ./Test/439.png
# Downloaded ./Test/438.png
# Downloaded ./Test/440.png
# Downloaded ./Test/441.png
# Downloaded ./Test/442.png
# Downloaded ./Test/443.png
# Downloaded ./Test/444.png
# Downloaded ./Test/447.png
# Downloaded ./Test/445.png
# Downloaded ./Test/446.png
# Downloaded ./Test/448.png
# Downloaded ./Test/450.png
# Downloaded ./Test/449.png
# Downloaded ./Test/451.png
# Downloaded ./Test/453.png
# Downloaded ./Test/452.png
# Downloaded ./Test/454.pngDownloaded ./Test/455.png
#
# Downloaded ./Test/456.png
# Downloaded ./Test/458.png
# Downloaded ./Test/457.png
# Downloaded ./Test/459.png
# Downloaded ./Test/460.png
# Downloaded ./Test/462.png
# Downloaded ./Test/463.png
# Downloaded ./Test/461.png
# Downloaded ./Test/464.png
# Downloaded ./Test/468.png
# Downloaded ./Test/465.png
# Downloaded ./Test/467.png
# Downloaded ./Test/469.png
# Downloaded ./Test/466.png
# Downloaded ./Test/472.png
# Downloaded ./Test/471.png
# Downloaded ./Test/470.png
# Downloaded ./Test/473.png
# Downloaded ./Test/474.png
# Downloaded ./Test/478.png
# Downloaded ./Test/477.png
# Downloaded ./Test/476.png
# Downloaded ./Test/481.png
# Downloaded ./Test/484.png
# Downloaded ./Test/482.png
# Downloaded ./Test/480.png
# Downloaded ./Test/487.png
# Downloaded ./Test/488.png
# Downloaded ./Test/489.png
# Downloaded ./Test/491.png
# Downloaded ./Test/490.png
# Downloaded ./Test/485.png
# Downloaded ./Test/475.png
# Downloaded ./Test/493.png
# Downloaded ./Test/486.png
# Downloaded ./Test/479.png
# Downloaded ./Test/483.png
# Downloaded ./Test/495.png
# Downloaded ./Test/498.png
# Downloaded ./Test/499.png
# Downloaded ./Test/504.png
# Downloaded ./Test/503.png
# Downloaded ./Test/505.png
# Downloaded ./Test/492.png
# Downloaded ./Test/506.png
# Downloaded ./Test/494.png
# Downloaded ./Test/507.png
# Downloaded ./Test/509.png
# Downloaded ./Test/508.png
# Downloaded ./Test/510.png
# Downloaded ./Test/496.png
# Downloaded ./Test/497.png
# Downloaded ./Test/500.png
# Downloaded ./Test/512.png
# Downloaded ./Test/511.png
# Downloaded ./Test/515.png
# Downloaded ./Test/513.png
# Downloaded ./Test/501.png
# Downloaded ./Test/514.png
# Downloaded ./Test/502.png
# Downloaded ./Test/516.png
# Downloaded ./Test/517.png
# Downloaded ./Test/519.png
# Downloaded ./Test/518.png
# Downloaded ./Test/520.png
# Downloaded ./Test/521.png
# Downloaded ./Test/522.png
# Downloaded ./Test/523.png
# Downloaded ./Test/524.png
# Downloaded ./Test/525.png
# Downloaded ./Test/526.png
# Downloaded ./Test/527.png
# Downloaded ./Test/528.png
# Downloaded ./Test/529.png
# Downloaded ./Test/530.png
# Downloaded ./Test/532.png
# Downloaded ./Test/541.png
# Downloaded ./Test/535.png
# Downloaded ./Test/538.png
# Downloaded ./Test/536.png
# Downloaded ./Test/533.png
# Downloaded ./Test/542.png
# Downloaded ./Test/537.png
# Downloaded ./Test/540.png
# Downloaded ./Test/531.png
# Downloaded ./Test/543.png
# Downloaded ./Test/534.png
# Downloaded ./Test/545.png
# Downloaded ./Test/549.png
# Downloaded ./Test/546.png
# Downloaded ./Test/548.png
# Downloaded ./Test/544.png
# Downloaded ./Test/551.png
# Downloaded ./Test/539.png
# Downloaded ./Test/553.png
# Downloaded ./Test/552.png
# Downloaded ./Test/550.png
# Downloaded ./Test/554.png
# Downloaded ./Test/556.png
# Downloaded ./Test/555.png
# Downloaded ./Test/559.png
# Downloaded ./Test/561.png
# Downloaded ./Test/547.png
# Downloaded ./Test/562.png
# Downloaded ./Test/560.png
# Downloaded ./Test/563.png
# Downloaded ./Test/565.png
# Downloaded ./Test/558.png
# Downloaded ./Test/567.png
# Downloaded ./Test/557.png
# Downloaded ./Test/568.png
# Downloaded ./Test/569.png
# Downloaded ./Test/571.png
# Downloaded ./Test/573.png
# Downloaded ./Test/564.png
# Downloaded ./Test/572.png
# Downloaded ./Test/570.png
# Downloaded ./Test/575.png
# Downloaded ./Test/566.png
# Downloaded ./Test/576.png
# Downloaded ./Test/577.png
# Downloaded ./Test/580.png
# Downloaded ./Test/582.png
# Downloaded ./Test/583.png
# Downloaded ./Test/584.png
# Downloaded ./Test/585.png
# Downloaded ./Test/574.png
# Downloaded ./Test/587.png
# Downloaded ./Test/588.png
# Downloaded ./Test/578.png
# Downloaded ./Test/581.png
# Downloaded ./Test/586.png
# Downloaded ./Test/579.png
# Downloaded ./Test/589.png
# Downloaded ./Test/598.png
# Downloaded ./Test/591.png
# Downloaded ./Test/592.png
# Downloaded ./Test/600.png
# Downloaded ./Test/599.png
# Downloaded ./Test/596.png
# Downloaded ./Test/590.png
# Downloaded ./Test/593.png
# Downloaded ./Test/594.png
# Downloaded ./Test/597.png
# Downloaded ./Test/595.png
# Downloaded ./Test/602.png
# Downloaded ./Test/608.png
# Downloaded ./Test/609.png
# Downloaded ./Test/612.png
# Downloaded ./Test/611.png
# Downloaded ./Test/603.png
# Downloaded ./Test/606.png
# Downloaded ./Test/601.png
# Downloaded ./Test/614.png
# Downloaded ./Test/604.png
# Downloaded ./Test/615.png
# Downloaded ./Test/605.png
# Downloaded ./Test/607.png
# Downloaded ./Test/616.png
# Downloaded ./Test/618.png
# Downloaded ./Test/610.png
# Downloaded ./Test/620.png
# Downloaded ./Test/613.png
# Downloaded ./Test/621.png
# Downloaded ./Test/622.png
# Downloaded ./Test/617.png
# Downloaded ./Test/623.png
# Downloaded ./Test/624.png
# Downloaded ./Test/628.png
# Downloaded ./Test/619.png
# Downloaded ./Test/629.png
# Downloaded ./Test/631.png
# Downloaded ./Test/632.png
# Downloaded ./Test/633.png
# Downloaded ./Test/634.png
# Downloaded ./Test/635.png
# Downloaded ./Test/636.png
# Downloaded ./Test/638.png
# Downloaded ./Test/627.png
# Downloaded ./Test/637.png
# Downloaded ./Test/639.png
# Downloaded ./Test/626.pngDownloaded ./Test/625.png
#
# Downloaded ./Test/640.png
# Downloaded ./Test/641.png
# Downloaded ./Test/643.png
# Downloaded ./Test/642.png
# Downloaded ./Test/644.png
# Downloaded ./Test/630.png
# Downloaded ./Test/646.png
# Downloaded ./Test/645.png
# Downloaded ./Test/648.png
# Downloaded ./Test/652.png
# Downloaded ./Test/653.png
# Downloaded ./Test/651.png
# Downloaded ./Test/654.png
# Downloaded ./Test/647.pngDownloaded ./Test/649.png
# Downloaded ./Test/655.png
#
# Downloaded ./Test/650.png
# Downloaded ./Test/656.png
# Downloaded ./Test/657.png
# Downloaded ./Test/658.png
# Downloaded ./Test/659.png
# Downloaded ./Test/660.png
# Downloaded ./Test/664.png
# Downloaded ./Test/662.png
# Downloaded ./Test/663.png
# Downloaded ./Test/661.png

# %%
Train_set.head()
# Out:
#          id observed_on                                          image_url  \
# 0   9865839  2017-06-24  https://inaturalist-open-data.s3.amazonaws.com...
# 1  10787160  2011-07-15  https://inaturalist-open-data.s3.amazonaws.com...
# 2  10787636  2011-07-29  https://inaturalist-open-data.s3.amazonaws.com...
# 3  10790153  2011-08-14  https://inaturalist-open-data.s3.amazonaws.com...
# 4  10799481  2012-05-26  https://inaturalist-open-data.s3.amazonaws.com...
#
#    num_identification_agreements   latitude  longitude phenology
# 0                              3 -33.983704  22.507295   Flowers
# 1                              6 -33.805170  22.195170   Flowers
# 2                              6 -33.369140  22.165330   Flowers
# 3                              4 -33.286420  23.510640   Flowers
# 4                              9 -33.835280  22.338470   Flowers

# %%
Train_labels = []
Test_Labels = []
for i in range(len(lastTrain_set)-5):
    Train_labels.append(lastTrain_set['phenology'][i])

for i in range(len(Test_set)):
    Test_Labels.append(Test_set['phenology'][i])

print(Train_labels)
print(len(Train_labels))
# Out:
# ['Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowers', 'Flowe ...
# 1857

# %%
import re

def extract_number(filename):
    # Use regex to find numbers in the filename
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else float('inf')

# %%
Test_image_list = []
Train_image_list = []
SIZE = 224
#Change path back to main folders
path_test = r".\Test\*.png"
path_train = r".\Train\*.png"

Test_image_list = sorted(glob.glob(path_test),key=lambda x: extract_number(os.path.basename(x)))
Train_image_list = sorted(glob.glob(path_train),key=lambda x: extract_number(os.path.basename(x)))

#Test_image_list = np.array(Test_image_list)
#Train_image_list  = np.array(Train_image_list)

# %%
Test_image_list
print(len(Train_image_list))
# Out:
# 1857

# %%
processedDF = pd.DataFrame({'image': Train_image_list,
                            'phenology': Train_labels})

# %%
processedDF.head()
# Out:
#            image phenology
# 0  .\Train\1.png   Flowers
# 1  .\Train\2.png   Flowers
# 2  .\Train\3.png   Flowers
# 3  .\Train\4.png   Flowers
# 4  .\Train\5.png   Flowers

# %%
processedDF['phenology'] = processedDF['phenology'].astype('category').cat.codes

# %%
# Image transformations (resize and normalize)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

class ImageDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        
        path = self.dataframe.iloc[idx]['image']
        label = self.dataframe.iloc[idx]['phenology']
        
        # load image
        image = Image.open(path).convert("RGB")
        
        # Apply transformations
        if self.transform:
            image = self.transform(image)

        label = torch.tensor(label, dtype=torch.long)
        
        return image, label

# Initialize dataset and dataloader
dataset = ImageDataset(dataframe=processedDF, transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class SingleLabelCNN(nn.Module):
    def __init__(self, num_classes):
        super(SingleLabelCNN, self).__init__()
        self.base_model = models.resnet18(pretrained=True)
        self.base_model.fc = nn.Linear(self.base_model.fc.in_features, num_classes)  # Adjust for single label output

    def forward(self, x):
        x = self.base_model(x)
        return nn.functional.log_softmax(x, dim=1)  # Use softmax for single-label classification

# Instantiate the model with the number of classes
num_classes = len(processedDF['phenology'].unique())  # Number of unique classes in the dataframe
model = SingleLabelCNN(num_classes).to(device)
# Out:
# c:\Users\micha\OneDrive\Documents\GitHub\AloeFeroxAlgorithm\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\micha\OneDrive\Documents\GitHub\AloeFeroxAlgorithm\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Define loss and optimizer
criterion = nn.CrossEntropyLoss()  # Cross-entropy for single-label classification
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training loop
num_epochs = 15
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    
    for image, label in dataloader:
        image = image.to(device)
        label = label.to(device)
        
        optimizer.zero_grad()
        outputs = model(image)
        loss = criterion(outputs, label)
        
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader):.4f}")
# Out:
# Epoch [1/15], Loss: 0.8687
# Epoch [2/15], Loss: 0.7456
# Epoch [3/15], Loss: 0.7267
# Epoch [4/15], Loss: 0.6118
# Epoch [5/15], Loss: 0.5447
# Epoch [6/15], Loss: 0.5475
# Epoch [7/15], Loss: 0.5188
# Epoch [8/15], Loss: 0.5293
# Epoch [9/15], Loss: 0.4734
# Epoch [10/15], Loss: 0.4404
# Epoch [11/15], Loss: 0.4480
# Epoch [12/15], Loss: 0.6535
# Epoch [13/15], Loss: 0.4454
# Epoch [14/15], Loss: 0.4059
# Epoch [15/15], Loss: 0.3862

# %%
model.eval()

# Initialize counters for accuracy
correct = 0
total = 0

# Turn off gradients
with torch.no_grad():
    for images, labels in dataloader:
        # Move data to the appropriate device
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass: get predictions
        outputs = model(images)
        
        # Get the predicted class with the highest score
        _, predicted = torch.max(outputs, 1)
        
        # Update total and correct counts
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# Calculate accuracy
accuracy = 100 * correct / total
print(f'Accuracy of the model on the test dataset: {accuracy:.2f}%')
# Out:
# Accuracy of the model on the test dataset: 83.95%

# %% [markdown]
# __Save model to torch file__

# %%
torch.save(model, 'final_model.pth')

# %% [markdown]
# __Load model from torch file__

# %%
loaded_model = torch.load('final_model.pth')
loaded_model.eval()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_17780\2595520329.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load('final_model.pth')
# SingleLabelCNN(
#   (base_model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %%
def preprocess_image(image_path, target_size=(224, 224)):
    preprocess = transforms.Compose([
        transforms.Resize(target_size),
        transforms.ToTensor(),  
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    img = Image.open(image_path)
    img_tensor = preprocess(img).unsqueeze(0)
    return img_tensor

# %%
# Path to the image you want to classify
image_path = 'Train/1.png'

# Preprocess the image
img_tensor = preprocess_image(image_path, target_size=(224, 224))

# Predict the class
with torch.no_grad():  # Disable gradient tracking
    output = loaded_model(img_tensor)
    predicted_class = torch.argmax(output, dim=1).item()

print(f'Predicted class: {predicted_class}')
# Out:
# Predicted class: 0

# %%
testDF = pd.DataFrame({'image': Test_image_list,
    'phenology': Test_Labels})
testDF['phenology'] = testDF['phenology'].astype('category').cat.codes

# %%
correct_outputs = 0

for _, row in testDF.iterrows():
    # Preprocess each image
    img_tensor = preprocess_image(row['image'])
    
    # Make prediction
    with torch.no_grad():  # No need for gradients during inference
        output = loaded_model(img_tensor)
        predicted_class = torch.argmax(output, dim=1).item()

    # Compare with the true label
    if predicted_class == row['phenology']:
        correct_outputs += 1

# Calculate accuracy
accuracy = correct_outputs / len(testDF)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 16.27%
